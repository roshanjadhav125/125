# %%
import pandas as pd

cars = pd.read_csv('/content/Automobile.csv')
cars.head( 10000)
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
cars[cars['origin'].isin(['europe','japan'])]
# Out:
#                              name   mpg  cylinders  displacement  horsepower  \
# 14          toyota corona mark ii  24.0          4         113.0        95.0
# 18                   datsun pl510  27.0          4          97.0        88.0
# 19   volkswagen 1131 deluxe sedan  26.0          4          97.0        46.0
# 20                    peugeot 504  25.0          4         110.0        87.0
# 21                    audi 100 ls  24.0          4         107.0        90.0
# ..                            ...   ...        ...           ...         ...
# 383                   honda civic  38.0          4          91.0        67.0
# 384            honda civic (auto)  32.0          4          91.0        67.0
# 385                 datsun 310 gx  38.0          4          91.0        67.0
# 390              toyota celica gt  32.0          4         144.0        96.0
# 394                     vw pickup  44.0          4          97.0        52.0
#
# ...

# %%
cars['weight']>3000
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: weight, Length: 398, dtype: bool

# %%
cars[cars['weight']>4000]
# Out:
#                          name   mpg  cylinders  displacement  horsepower  \
# 5            ford galaxie 500  15.0          8         429.0       198.0
# 6            chevrolet impala  14.0          8         454.0       220.0
# 7           plymouth fury iii  14.0          8         440.0       215.0
# 8            pontiac catalina  14.0          8         455.0       225.0
# 25                  ford f250  10.0          8         360.0       215.0
# ..                        ...   ...        ...           ...         ...
# 231          chrysler cordoba  15.5          8         400.0       190.0
# 232          ford thunderbird  16.0          8         351.0       149.0
# 265           dodge magnum xe  17.5          8         318.0       140.0
# 289   buick estate wagon (sw)  16.9          8         350.0       155.0
# 290  ford country squire (sw)  15.5          8         351.0       142.0
#
#      weight  acceleration  model_year origin
# 5      4341          10.0          70    usa
# ...

# %%
cars[~(cars['weight']>4000)]
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
cars['mpg']=cars['mpg'].apply(lambda x:x+3)
cars
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  21.0          8         307.0       130.0
# 1            buick skylark 320  18.0          8         350.0       165.0
# 2           plymouth satellite  21.0          8         318.0       150.0
# 3                amc rebel sst  19.0          8         304.0       150.0
# 4                  ford torino  20.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  30.0          4         140.0        86.0
# 394                  vw pickup  47.0          4          97.0        52.0
# 395              dodge rampage  35.0          4         135.0        84.0
# 396                ford ranger  31.0          4         120.0        79.0
# 397                 chevy s-10  34.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
cars.shape
# Out:
# (398, 9)

# %%
cars.isnull()
# Out:
#       name    mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False  False      False         False       False   False         False
# 1    False  False      False         False       False   False         False
# 2    False  False      False         False       False   False         False
# 3    False  False      False         False       False   False         False
# 4    False  False      False         False       False   False         False
# ..     ...    ...        ...           ...         ...     ...           ...
# 393  False  False      False         False       False   False         False
# 394  False  False      False         False       False   False         False
# 395  False  False      False         False       False   False         False
# 396  False  False      False         False       False   False         False
# 397  False  False      False         False       False   False         False
#
#      model_year  origin
# ...

# %%
cars.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
cars['name'].value_counts()
# Out:
# ford pinto             6
# toyota corolla         5
# amc matador            5
# ford maverick          5
# chevrolet chevette     4
#                       ..
# chevrolet monza 2+2    1
# ford mustang ii        1
# pontiac astro          1
# amc pacer              1
# chevy s-10             1
# Name: name, Length: 305, dtype: int64

# %%
cars[cars['origin'].isin(['europe'])]
# Out:
#                              name   mpg  cylinders  displacement  horsepower  \
# 19   volkswagen 1131 deluxe sedan  29.0          4          97.0        46.0
# 20                    peugeot 504  28.0          4         110.0        87.0
# 21                    audi 100 ls  27.0          4         107.0        90.0
# 22                       saab 99e  28.0          4         104.0        95.0
# 23                       bmw 2002  29.0          4         121.0       113.0
# ..                            ...   ...        ...           ...         ...
# 354                   renault 18i  37.5          4         100.0         NaN
# 359     peugeot 505s turbo diesel  31.1          4         141.0        80.0
# 360                  volvo diesel  33.7          6         145.0        76.0
# 375           volkswagen rabbit l  39.0          4         105.0        74.0
# 394                     vw pickup  47.0          4          97.0        52.0
#
# ...
